# %% [markdown]
# # Cell Balancing using a Genetic Algorithm
#
# ## Problem Statement
#
# - Our study has a global "Audience" (demographic) set that needs to be fulfilled.
# - We have a limited number of Highlighters.
# - In our study, we have Cells (pairing of instructions <-> audience)
# - It's possible for the audiences of each Cell to overlap.
# - We therefore have a constraint satisfaction problem. Given a finite list of Highlighters, how do we distribute those Highlighters to Cells so that we maximize our distribution and minimize our chance of not being able to fill one of the Cells?

# %% [markdown]
# ## Defining Classes and Configuration:

# %%
import random 

class Highlighter:
    def __init__(self, name):
        self.name = name
        self.assignable_buckets = []

    def __str__(self):
        return f"Highlighter: {self.name}, assignable_buckets: {self.assignable_buckets}"

# Buckets are what we need to fill.
class Bucket:
    def __init__(self, name, percent_fillable, fill_goal):
        self.name = name
        # How many of the available Highlighters can fit into this bucket
        self.percent_fillable = percent_fillable
        self.highlighters = []
        # How many Highlighters are needed to fill that bucket
        self.fill_goal = fill_goal

    def score(self):
        return 1

# Things to configure
buckets = [
    Bucket("A", 20, 1000),
    Bucket("B", 20, 2000),
    Bucket("C", 60, 3000),
    Bucket("D", 30, 3000),
    Bucket("E", 10, 1000),
]

NUM_HIGHLIGHTERS = 10000

highlighters = [Highlighter(f"H_{i:03d}") for i in range(NUM_HIGHLIGHTERS)]

# Configure randomly which Highlighters can be assigned to which buckets
for bucket in buckets:
    fillable = bucket.percent_fillable / 100.0
    num_highlighters_to_assign = int(NUM_HIGHLIGHTERS * fillable)
    
    hlers_to_add_bucket_to = random.sample(highlighters, num_highlighters_to_assign)
    for h in hlers_to_add_bucket_to:
        h.assignable_buckets.append(bucket.name)

for h in highlighters:
    print(h)

# filter out highlighters that have no possible assignment
highlighters = [h for h in highlighters if len(h.assignable_buckets) > 0]
# Out:
# Highlighter: H_000, assignable_buckets: ['D']
# Highlighter: H_001, assignable_buckets: ['C']
# Highlighter: H_002, assignable_buckets: []
# Highlighter: H_003, assignable_buckets: ['C']
# Highlighter: H_004, assignable_buckets: ['A', 'C']
# Highlighter: H_005, assignable_buckets: []
# Highlighter: H_006, assignable_buckets: []
# Highlighter: H_007, assignable_buckets: ['C', 'D']
# Highlighter: H_008, assignable_buckets: []
# Highlighter: H_009, assignable_buckets: ['B', 'C']
# Highlighter: H_010, assignable_buckets: ['C']
# Highlighter: H_011, assignable_buckets: ['C']
# Highlighter: H_012, assignable_buckets: ['A']
# Highlighter: H_013, assignable_buckets: ['C', 'D']
# Highlighter: H_014, assignable_buckets: []
# Highlighter: H_015, assignable_buckets: ['B', 'C']
# Highlighter: H_016, assignable_buckets: ['C', 'D']
# Highlighter: H_017, assignable_buckets: ['C', 'D']
# Highlighter: H_018, assignable_buckets: ['C']
# Highlighter: H_019, assignable_buckets: ['C', 'D']
# Highlighter: H_020, assignable_buckets: ['A', 'C', 'E']
# Highlighter: H_021, assignable_buckets: ['C', 'D']
# Highlighter: H_022, assignable_buckets: []
# Highlighter: H_023, assignable_buckets: ['B']
# Highlighter: H_024, assignable_buckets: ['C']
# Highlighter: H_025, assignable_buckets: ['B']
# Highlighter: H_026, assignable_buckets: ['C']
# Highlighter: H_027, assignable_buckets: ['A', 'C']
# Highlighter: H_028, assignable_buckets: ['C']
# Highlighter: H_029, assignable_buckets: ['C', 'E']
# Highlighter: H_030, assignable_buckets: ['C', 'D']
# Highlighter: H_031, assignable_buckets: ['A', 'C']
# Highlighter: H_032, assignable_buckets: ['A', 'B', 'C', 'D', 'E']
# Highlighter: H_033, assignable_buckets: ['A']
# Highlighter: H_034, assignable_buckets: ['C']
# Highlighter: H_035, assignable_buckets: ['D']
# Highlighter: H_036, assignable_buckets: ['C']
# Highlighter: H_037, assignable_buckets: []
# Highlighter: H_038, assignable_buckets: ['D']
# Highlighter: H_039, assignable_buckets: ['C', 'D', 'E']
# Highlighter: H_040, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_041, assignable_buckets: ['C', 'D', 'E']
# Highlighter: H_042, assignable_buckets: []
# Highlighter: H_043, assignable_buckets: ['B', 'C']
# Highlighter: H_044, assignable_buckets: ['C']
# Highlighter: H_045, assignable_buckets: ['C', 'D']
# Highlighter: H_046, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_047, assignable_buckets: ['A', 'C']
# Highlighter: H_048, assignable_buckets: ['C']
# Highlighter: H_049, assignable_buckets: ['C', 'D', 'E']
# Highlighter: H_050, assignable_buckets: []
# Highlighter: H_051, assignable_buckets: ['C']
# Highlighter: H_052, assignable_buckets: ['B']
# Highlighter: H_053, assignable_buckets: ['C']
# Highlighter: H_054, assignable_buckets: ['C']
# Highlighter: H_055, assignable_buckets: ['C']
# Highlighter: H_056, assignable_buckets: ['A', 'B', 'C', 'D']
# Highlighter: H_057, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_058, assignable_buckets: ['C']
# Highlighter: H_059, assignable_buckets: []
# Highlighter: H_060, assignable_buckets: ['A', 'C']
# Highlighter: H_061, assignable_buckets: []
# Highlighter: H_062, assignable_buckets: ['B', 'C']
# Highlighter: H_063, assignable_buckets: ['C', 'D']
# Highlighter: H_064, assignable_buckets: ['C']
# Highlighter: H_065, assignable_buckets: ['C']
# Highlighter: H_066, assignable_buckets: ['A', 'C', 'D', 'E']
# Highlighter: H_067, assignable_buckets: ['C', 'E']
# Highlighter: H_068, assignable_buckets: ['C', 'D']
# Highlighter: H_069, assignable_buckets: ['A', 'B', 'C', 'D']
# Highlighter: H_070, assignable_buckets: []
# Highlighter: H_071, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_072, assignable_buckets: ['C']
# Highlighter: H_073, assignable_buckets: ['B']
# Highlighter: H_074, assignable_buckets: ['C']
# Highlighter: H_075, assignable_buckets: ['A', 'C']
# Highlighter: H_076, assignable_buckets: ['B', 'C']
# Highlighter: H_077, assignable_buckets: ['C']
# Highlighter: H_078, assignable_buckets: ['C']
# Highlighter: H_079, assignable_buckets: []
# Highlighter: H_080, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_081, assignable_buckets: ['A', 'C']
# Highlighter: H_082, assignable_buckets: []
# Highlighter: H_083, assignable_buckets: ['A', 'C']
# Highlighter: H_084, assignable_buckets: ['D']
# Highlighter: H_085, assignable_buckets: ['C', 'E']
# Highlighter: H_086, assignable_buckets: ['B', 'C']
# Highlighter: H_087, assignable_buckets: ['B']
# Highlighter: H_088, assignable_buckets: []
# Highlighter: H_089, assignable_buckets: []
# Highlighter: H_090, assignable_buckets: ['C', 'E']
# Highlighter: H_091, assignable_buckets: []
# Highlighter: H_092, assignable_buckets: ['C']
# Highlighter: H_093, assignable_buckets: ['A', 'D']
# Highlighter: H_094, assignable_buckets: []
# Highlighter: H_095, assignable_buckets: ['C']
# Highlighter: H_096, assignable_buckets: []
# Highlighter: H_097, assignable_buckets: ['C', 'D']
# Highlighter: H_098, assignable_buckets: ['B', 'C', 'E']
# Highlighter: H_099, assignable_buckets: ['B']
# Highlighter: H_100, assignable_buckets: ['C']
# Highlighter: H_101, assignable_buckets: ['B', 'C']
# Highlighter: H_102, assignable_buckets: ['C']
# Highlighter: H_103, assignable_buckets: ['B']
# Highlighter: H_104, assignable_buckets: ['C']
# Highlighter: H_105, assignable_buckets: ['C']
# Highlighter: H_106, assignable_buckets: ['B']
# Highlighter: H_107, assignable_buckets: []
# Highlighter: H_108, assignable_buckets: ['C', 'E']
# Highlighter: H_109, assignable_buckets: ['E']
# Highlighter: H_110, assignable_buckets: ['C']
# Highlighter: H_111, assignable_buckets: ['C']
# Highlighter: H_112, assignable_buckets: ['C']
# Highlighter: H_113, assignable_buckets: ['D']
# Highlighter: H_114, assignable_buckets: ['B']
# Highlighter: H_115, assignable_buckets: ['B', 'C']
# Highlighter: H_116, assignable_buckets: []
# Highlighter: H_117, assignable_buckets: ['A']
# Highlighter: H_118, assignable_buckets: ['A', 'D']
# Highlighter: H_119, assignable_buckets: ['C', 'D']
# Highlighter: H_120, assignable_buckets: ['B', 'E']
# Highlighter: H_121, assignable_buckets: ['E']
# Highlighter: H_122, assignable_buckets: ['D']
# Highlighter: H_123, assignable_buckets: ['C', 'D']
# Highlighter: H_124, assignable_buckets: ['E']
# Highlighter: H_125, assignable_buckets: []
# Highlighter: H_126, assignable_buckets: ['C']
# Highlighter: H_127, assignable_buckets: ['C', 'D']
# Highlighter: H_128, assignable_buckets: []
# Highlighter: H_129, assignable_buckets: ['D']
# Highlighter: H_130, assignable_buckets: ['A', 'C']
# Highlighter: H_131, assignable_buckets: ['D']
# Highlighter: H_132, assignable_buckets: ['C']
# Highlighter: H_133, assignable_buckets: ['C']
# Highlighter: H_134, assignable_buckets: ['D']
# Highlighter: H_135, assignable_buckets: ['C', 'D', 'E']
# Highlighter: H_136, assignable_buckets: ['B', 'C']
# Highlighter: H_137, assignable_buckets: ['D']
# Highlighter: H_138, assignable_buckets: ['C']
# Highlighter: H_139, assignable_buckets: ['C']
# Highlighter: H_140, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_141, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_142, assignable_buckets: []
# Highlighter: H_143, assignable_buckets: ['B', 'D']
# Highlighter: H_144, assignable_buckets: ['C', 'D', 'E']
# Highlighter: H_145, assignable_buckets: ['A', 'C', 'D', 'E']
# Highlighter: H_146, assignable_buckets: ['A', 'D']
# Highlighter: H_147, assignable_buckets: []
# Highlighter: H_148, assignable_buckets: ['C']
# Highlighter: H_149, assignable_buckets: ['A', 'C']
# Highlighter: H_150, assignable_buckets: ['C']
# Highlighter: H_151, assignable_buckets: ['A', 'B', 'D']
# Highlighter: H_152, assignable_buckets: ['C']
# Highlighter: H_153, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_154, assignable_buckets: ['A', 'B', 'C', 'D']
# Highlighter: H_155, assignable_buckets: ['B', 'C']
# Highlighter: H_156, assignable_buckets: ['C']
# Highlighter: H_157, assignable_buckets: ['B', 'C']
# Highlighter: H_158, assignable_buckets: ['A', 'C']
# Highlighter: H_159, assignable_buckets: []
# Highlighter: H_160, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_161, assignable_buckets: ['C']
# Highlighter: H_162, assignable_buckets: ['C']
# Highlighter: H_163, assignable_buckets: ['D']
# Highlighter: H_164, assignable_buckets: ['C']
# Highlighter: H_165, assignable_buckets: ['C', 'D']
# Highlighter: H_166, assignable_buckets: []
# Highlighter: H_167, assignable_buckets: ['B', 'C']
# Highlighter: H_168, assignable_buckets: []
# Highlighter: H_169, assignable_buckets: ['C', 'E']
# Highlighter: H_170, assignable_buckets: ['A', 'C']
# Highlighter: H_171, assignable_buckets: ['C']
# Highlighter: H_172, assignable_buckets: ['A']
# Highlighter: H_173, assignable_buckets: ['D']
# Highlighter: H_174, assignable_buckets: ['C', 'D']
# Highlighter: H_175, assignable_buckets: ['C']
# Highlighter: H_176, assignable_buckets: ['B', 'C']
# Highlighter: H_177, assignable_buckets: ['C', 'D']
# Highlighter: H_178, assignable_buckets: ['C']
# Highlighter: H_179, assignable_buckets: ['A']
# Highlighter: H_180, assignable_buckets: ['A', 'C']
# Highlighter: H_181, assignable_buckets: ['D']
# Highlighter: H_182, assignable_buckets: ['B']
# Highlighter: H_183, assignable_buckets: ['C']
# Highlighter: H_184, assignable_buckets: ['C', 'E']
# Highlighter: H_185, assignable_buckets: ['C']
# Highlighter: H_186, assignable_buckets: ['D']
# Highlighter: H_187, assignable_buckets: []
# Highlighter: H_188, assignable_buckets: ['E']
# Highlighter: H_189, assignable_buckets: []
# Highlighter: H_190, assignable_buckets: []
# Highlighter: H_191, assignable_buckets: ['A']
# Highlighter: H_192, assignable_buckets: ['C', 'D']
# Highlighter: H_193, assignable_buckets: []
# Highlighter: H_194, assignable_buckets: ['C', 'D']
# Highlighter: H_195, assignable_buckets: ['B']
# Highlighter: H_196, assignable_buckets: ['C', 'D']
# Highlighter: H_197, assignable_buckets: ['A']
# Highlighter: H_198, assignable_buckets: ['B', 'D']
# Highlighter: H_199, assignable_buckets: []
# Highlighter: H_200, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_201, assignable_buckets: ['B', 'D']
# Highlighter: H_202, assignable_buckets: ['C', 'E']
# Highlighter: H_203, assignable_buckets: ['C']
# Highlighter: H_204, assignable_buckets: ['D']
# Highlighter: H_205, assignable_buckets: ['A', 'C']
# Highlighter: H_206, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_207, assignable_buckets: ['C', 'D']
# Highlighter: H_208, assignable_buckets: ['C', 'D']
# Highlighter: H_209, assignable_buckets: ['C']
# Highlighter: H_210, assignable_buckets: ['B', 'C']
# Highlighter: H_211, assignable_buckets: []
# Highlighter: H_212, assignable_buckets: ['C']
# Highlighter: H_213, assignable_buckets: []
# Highlighter: H_214, assignable_buckets: ['C']
# Highlighter: H_215, assignable_buckets: []
# Highlighter: H_216, assignable_buckets: ['C']
# Highlighter: H_217, assignable_buckets: ['C', 'D']
# Highlighter: H_218, assignable_buckets: ['C', 'D']
# Highlighter: H_219, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_220, assignable_buckets: ['A', 'C', 'D', 'E']
# Highlighter: H_221, assignable_buckets: ['C', 'D', 'E']
# Highlighter: H_222, assignable_buckets: ['B']
# Highlighter: H_223, assignable_buckets: ['C']
# Highlighter: H_224, assignable_buckets: ['C']
# Highlighter: H_225, assignable_buckets: ['A', 'C', 'D', 'E']
# Highlighter: H_226, assignable_buckets: ['D', 'E']
# Highlighter: H_227, assignable_buckets: ['D']
# Highlighter: H_228, assignable_buckets: ['C', 'D']
# Highlighter: H_229, assignable_buckets: ['B', 'D']
# Highlighter: H_230, assignable_buckets: ['B', 'C']
# Highlighter: H_231, assignable_buckets: ['C']
# Highlighter: H_232, assignable_buckets: ['A', 'D']
# Highlighter: H_233, assignable_buckets: ['B']
# Highlighter: H_234, assignable_buckets: ['C']
# Highlighter: H_235, assignable_buckets: ['A', 'C', 'E']
# Highlighter: H_236, assignable_buckets: ['B', 'D', 'E']
# Highlighter: H_237, assignable_buckets: ['B', 'C']
# Highlighter: H_238, assignable_buckets: ['A', 'C']
# Highlighter: H_239, assignable_buckets: ['C', 'D']
# Highlighter: H_240, assignable_buckets: []
# Highlighter: H_241, assignable_buckets: ['C', 'E']
# Highlighter: H_242, assignable_buckets: ['C']
# Highlighter: H_243, assignable_buckets: ['C', 'D']
# Highlighter: H_244, assignable_buckets: ['A']
# Highlighter: H_245, assignable_buckets: []
# Highlighter: H_246, assignable_buckets: ['C', 'D']
# Highlighter: H_247, assignable_buckets: ['E']
# Highlighter: H_248, assignable_buckets: []
# Highlighter: H_249, assignable_buckets: ['B', 'C']
# Highlighter: H_250, assignable_buckets: ['C']
# Highlighter: H_251, assignable_buckets: ['D']
# Highlighter: H_252, assignable_buckets: ['B', 'C']
# Highlighter: H_253, assignable_buckets: ['A']
# Highlighter: H_254, assignable_buckets: ['B']
# Highlighter: H_255, assignable_buckets: ['A']
# Highlighter: H_256, assignable_buckets: ['A', 'D']
# Highlighter: H_257, assignable_buckets: ['D']
# Highlighter: H_258, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_259, assignable_buckets: []
# Highlighter: H_260, assignable_buckets: ['A']
# Highlighter: H_261, assignable_buckets: ['C']
# Highlighter: H_262, assignable_buckets: ['C', 'D']
# Highlighter: H_263, assignable_buckets: ['C', 'D']
# Highlighter: H_264, assignable_buckets: ['A', 'C']
# Highlighter: H_265, assignable_buckets: ['D']
# Highlighter: H_266, assignable_buckets: []
# Highlighter: H_267, assignable_buckets: ['C']
# Highlighter: H_268, assignable_buckets: ['C']
# Highlighter: H_269, assignable_buckets: ['D']
# Highlighter: H_270, assignable_buckets: ['C', 'D']
# Highlighter: H_271, assignable_buckets: ['C']
# Highlighter: H_272, assignable_buckets: ['B', 'C', 'E']
# Highlighter: H_273, assignable_buckets: ['C']
# Highlighter: H_274, assignable_buckets: ['C', 'E']
# Highlighter: H_275, assignable_buckets: ['C']
# Highlighter: H_276, assignable_buckets: ['C']
# Highlighter: H_277, assignable_buckets: ['C']
# Highlighter: H_278, assignable_buckets: ['C', 'D']
# Highlighter: H_279, assignable_buckets: ['C']
# Highlighter: H_280, assignable_buckets: ['C', 'E']
# Highlighter: H_281, assignable_buckets: []
# Highlighter: H_282, assignable_buckets: ['A', 'D']
# Highlighter: H_283, assignable_buckets: ['C']
# Highlighter: H_284, assignable_buckets: ['B']
# Highlighter: H_285, assignable_buckets: ['C', 'E']
# Highlighter: H_286, assignable_buckets: ['C', 'D']
# Highlighter: H_287, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_288, assignable_buckets: ['A']
# Highlighter: H_289, assignable_buckets: ['B', 'C']
# Highlighter: H_290, assignable_buckets: ['A']
# Highlighter: H_291, assignable_buckets: ['C', 'D']
# Highlighter: H_292, assignable_buckets: ['C']
# Highlighter: H_293, assignable_buckets: ['A', 'C']
# Highlighter: H_294, assignable_buckets: ['D']
# Highlighter: H_295, assignable_buckets: []
# Highlighter: H_296, assignable_buckets: []
# Highlighter: H_297, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_298, assignable_buckets: ['C']
# Highlighter: H_299, assignable_buckets: ['C']
# Highlighter: H_300, assignable_buckets: []
# Highlighter: H_301, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_302, assignable_buckets: ['C', 'D']
# Highlighter: H_303, assignable_buckets: ['C']
# Highlighter: H_304, assignable_buckets: ['C']
# Highlighter: H_305, assignable_buckets: ['B']
# Highlighter: H_306, assignable_buckets: ['B', 'C']
# Highlighter: H_307, assignable_buckets: []
# Highlighter: H_308, assignable_buckets: ['C']
# Highlighter: H_309, assignable_buckets: []
# Highlighter: H_310, assignable_buckets: ['D']
# Highlighter: H_311, assignable_buckets: ['A', 'C']
# Highlighter: H_312, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_313, assignable_buckets: ['A']
# Highlighter: H_314, assignable_buckets: ['C']
# Highlighter: H_315, assignable_buckets: ['C']
# Highlighter: H_316, assignable_buckets: ['C']
# Highlighter: H_317, assignable_buckets: ['C']
# Highlighter: H_318, assignable_buckets: ['B', 'C']
# Highlighter: H_319, assignable_buckets: ['C']
# Highlighter: H_320, assignable_buckets: ['D']
# Highlighter: H_321, assignable_buckets: ['C']
# Highlighter: H_322, assignable_buckets: ['B', 'C']
# Highlighter: H_323, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_324, assignable_buckets: ['C']
# Highlighter: H_325, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_326, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_327, assignable_buckets: ['C']
# Highlighter: H_328, assignable_buckets: ['A']
# Highlighter: H_329, assignable_buckets: ['C']
# Highlighter: H_330, assignable_buckets: ['C']
# Highlighter: H_331, assignable_buckets: ['C']
# Highlighter: H_332, assignable_buckets: ['B', 'C']
# Highlighter: H_333, assignable_buckets: []
# Highlighter: H_334, assignable_buckets: ['B', 'C']
# Highlighter: H_335, assignable_buckets: ['B', 'C']
# Highlighter: H_336, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_337, assignable_buckets: ['D']
# Highlighter: H_338, assignable_buckets: ['C', 'E']
# Highlighter: H_339, assignable_buckets: ['A', 'C']
# Highlighter: H_340, assignable_buckets: ['B', 'C']
# Highlighter: H_341, assignable_buckets: ['A', 'C']
# Highlighter: H_342, assignable_buckets: ['A', 'C']
# Highlighter: H_343, assignable_buckets: ['C']
# Highlighter: H_344, assignable_buckets: ['B', 'C']
# Highlighter: H_345, assignable_buckets: ['C']
# Highlighter: H_346, assignable_buckets: []
# Highlighter: H_347, assignable_buckets: ['A']
# Highlighter: H_348, assignable_buckets: ['A', 'C']
# Highlighter: H_349, assignable_buckets: ['A', 'C']
# Highlighter: H_350, assignable_buckets: ['C']
# Highlighter: H_351, assignable_buckets: []
# Highlighter: H_352, assignable_buckets: []
# Highlighter: H_353, assignable_buckets: ['C']
# Highlighter: H_354, assignable_buckets: []
# Highlighter: H_355, assignable_buckets: ['B', 'D', 'E']
# Highlighter: H_356, assignable_buckets: ['C']
# Highlighter: H_357, assignable_buckets: []
# Highlighter: H_358, assignable_buckets: []
# Highlighter: H_359, assignable_buckets: []
# Highlighter: H_360, assignable_buckets: ['B']
# Highlighter: H_361, assignable_buckets: ['C']
# Highlighter: H_362, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_363, assignable_buckets: ['B', 'C']
# Highlighter: H_364, assignable_buckets: ['D']
# Highlighter: H_365, assignable_buckets: ['B', 'C']
# Highlighter: H_366, assignable_buckets: []
# Highlighter: H_367, assignable_buckets: ['C']
# Highlighter: H_368, assignable_buckets: ['A', 'C']
# Highlighter: H_369, assignable_buckets: ['A']
# Highlighter: H_370, assignable_buckets: ['D']
# Highlighter: H_371, assignable_buckets: ['E']
# Highlighter: H_372, assignable_buckets: ['C']
# Highlighter: H_373, assignable_buckets: []
# Highlighter: H_374, assignable_buckets: []
# Highlighter: H_375, assignable_buckets: ['A']
# Highlighter: H_376, assignable_buckets: ['A', 'C']
# Highlighter: H_377, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_378, assignable_buckets: ['A']
# Highlighter: H_379, assignable_buckets: []
# Highlighter: H_380, assignable_buckets: ['C']
# Highlighter: H_381, assignable_buckets: ['C', 'D']
# Highlighter: H_382, assignable_buckets: ['D']
# Highlighter: H_383, assignable_buckets: ['D']
# Highlighter: H_384, assignable_buckets: ['D']
# Highlighter: H_385, assignable_buckets: ['C']
# Highlighter: H_386, assignable_buckets: ['C', 'D']
# Highlighter: H_387, assignable_buckets: ['C']
# Highlighter: H_388, assignable_buckets: ['C']
# Highlighter: H_389, assignable_buckets: ['A', 'C']
# Highlighter: H_390, assignable_buckets: ['A', 'C']
# Highlighter: H_391, assignable_buckets: ['B', 'C']
# Highlighter: H_392, assignable_buckets: ['A']
# Highlighter: H_393, assignable_buckets: ['B', 'C', 'E']
# Highlighter: H_394, assignable_buckets: []
# Highlighter: H_395, assignable_buckets: []
# Highlighter: H_396, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_397, assignable_buckets: ['A', 'C']
# Highlighter: H_398, assignable_buckets: []
# Highlighter: H_399, assignable_buckets: ['C']
# Highlighter: H_400, assignable_buckets: ['C']
# Highlighter: H_401, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_402, assignable_buckets: ['C']
# Highlighter: H_403, assignable_buckets: []
# Highlighter: H_404, assignable_buckets: []
# Highlighter: H_405, assignable_buckets: ['C']
# Highlighter: H_406, assignable_buckets: []
# Highlighter: H_407, assignable_buckets: ['C']
# Highlighter: H_408, assignable_buckets: ['C', 'D', 'E']
# Highlighter: H_409, assignable_buckets: ['E']
# Highlighter: H_410, assignable_buckets: ['C', 'E']
# Highlighter: H_411, assignable_buckets: ['C']
# Highlighter: H_412, assignable_buckets: ['A', 'C']
# Highlighter: H_413, assignable_buckets: []
# Highlighter: H_414, assignable_buckets: ['A']
# Highlighter: H_415, assignable_buckets: []
# Highlighter: H_416, assignable_buckets: ['A', 'C']
# Highlighter: H_417, assignable_buckets: []
# Highlighter: H_418, assignable_buckets: ['C', 'E']
# Highlighter: H_419, assignable_buckets: []
# Highlighter: H_420, assignable_buckets: []
# Highlighter: H_421, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_422, assignable_buckets: ['B', 'D']
# Highlighter: H_423, assignable_buckets: ['C']
# Highlighter: H_424, assignable_buckets: ['C']
# Highlighter: H_425, assignable_buckets: []
# Highlighter: H_426, assignable_buckets: ['A']
# Highlighter: H_427, assignable_buckets: ['C']
# Highlighter: H_428, assignable_buckets: ['C', 'E']
# Highlighter: H_429, assignable_buckets: ['C', 'E']
# Highlighter: H_430, assignable_buckets: ['C']
# Highlighter: H_431, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_432, assignable_buckets: ['C']
# Highlighter: H_433, assignable_buckets: ['C']
# Highlighter: H_434, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_435, assignable_buckets: ['B']
# Highlighter: H_436, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_437, assignable_buckets: []
# Highlighter: H_438, assignable_buckets: ['B', 'C']
# Highlighter: H_439, assignable_buckets: ['C']
# Highlighter: H_440, assignable_buckets: ['C']
# Highlighter: H_441, assignable_buckets: []
# Highlighter: H_442, assignable_buckets: ['C']
# Highlighter: H_443, assignable_buckets: ['B', 'C']
# Highlighter: H_444, assignable_buckets: ['B', 'C']
# Highlighter: H_445, assignable_buckets: ['C']
# Highlighter: H_446, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_447, assignable_buckets: []
# Highlighter: H_448, assignable_buckets: ['A']
# Highlighter: H_449, assignable_buckets: ['C', 'D']
# Highlighter: H_450, assignable_buckets: ['B']
# Highlighter: H_451, assignable_buckets: []
# Highlighter: H_452, assignable_buckets: ['C', 'D']
# Highlighter: H_453, assignable_buckets: []
# Highlighter: H_454, assignable_buckets: []
# Highlighter: H_455, assignable_buckets: ['A', 'C']
# Highlighter: H_456, assignable_buckets: ['C', 'D']
# Highlighter: H_457, assignable_buckets: ['C']
# Highlighter: H_458, assignable_buckets: []
# Highlighter: H_459, assignable_buckets: ['D']
# Highlighter: H_460, assignable_buckets: ['C']
# Highlighter: H_461, assignable_buckets: []
# Highlighter: H_462, assignable_buckets: []
# Highlighter: H_463, assignable_buckets: ['C', 'D', 'E']
# Highlighter: H_464, assignable_buckets: ['D']
# Highlighter: H_465, assignable_buckets: ['C']
# Highlighter: H_466, assignable_buckets: ['C', 'D']
# Highlighter: H_467, assignable_buckets: ['C']
# Highlighter: H_468, assignable_buckets: ['B', 'D']
# Highlighter: H_469, assignable_buckets: []
# Highlighter: H_470, assignable_buckets: ['B', 'C']
# Highlighter: H_471, assignable_buckets: []
# Highlighter: H_472, assignable_buckets: ['C']
# Highlighter: H_473, assignable_buckets: ['C', 'E']
# Highlighter: H_474, assignable_buckets: ['A', 'C']
# Highlighter: H_475, assignable_buckets: ['D']
# Highlighter: H_476, assignable_buckets: ['C', 'E']
# Highlighter: H_477, assignable_buckets: ['A', 'B']
# Highlighter: H_478, assignable_buckets: []
# Highlighter: H_479, assignable_buckets: []
# Highlighter: H_480, assignable_buckets: ['D']
# Highlighter: H_481, assignable_buckets: ['C', 'D']
# Highlighter: H_482, assignable_buckets: ['C']
# Highlighter: H_483, assignable_buckets: ['D']
# Highlighter: H_484, assignable_buckets: ['C']
# Highlighter: H_485, assignable_buckets: ['C', 'D']
# Highlighter: H_486, assignable_buckets: ['C', 'D']
# Highlighter: H_487, assignable_buckets: []
# Highlighter: H_488, assignable_buckets: ['A', 'D']
# Highlighter: H_489, assignable_buckets: ['C', 'D']
# Highlighter: H_490, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_491, assignable_buckets: ['D', 'E']
# Highlighter: H_492, assignable_buckets: ['A', 'C']
# Highlighter: H_493, assignable_buckets: ['B', 'C']
# Highlighter: H_494, assignable_buckets: []
# Highlighter: H_495, assignable_buckets: ['A', 'C']
# Highlighter: H_496, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_497, assignable_buckets: ['B', 'C']
# Highlighter: H_498, assignable_buckets: []
# Highlighter: H_499, assignable_buckets: ['C']
# Highlighter: H_500, assignable_buckets: ['A', 'B']
# Highlighter: H_501, assignable_buckets: ['C']
# Highlighter: H_502, assignable_buckets: []
# Highlighter: H_503, assignable_buckets: []
# Highlighter: H_504, assignable_buckets: []
# Highlighter: H_505, assignable_buckets: ['D']
# Highlighter: H_506, assignable_buckets: ['C', 'D']
# Highlighter: H_507, assignable_buckets: []
# Highlighter: H_508, assignable_buckets: ['C']
# Highlighter: H_509, assignable_buckets: ['A', 'C']
# Highlighter: H_510, assignable_buckets: ['B', 'C', 'E']
# Highlighter: H_511, assignable_buckets: ['A', 'C']
# Highlighter: H_512, assignable_buckets: ['C', 'E']
# Highlighter: H_513, assignable_buckets: ['A', 'B', 'E']
# Highlighter: H_514, assignable_buckets: ['C', 'E']
# Highlighter: H_515, assignable_buckets: ['A', 'C']
# Highlighter: H_516, assignable_buckets: ['A']
# Highlighter: H_517, assignable_buckets: []
# Highlighter: H_518, assignable_buckets: ['C']
# Highlighter: H_519, assignable_buckets: ['C']
# Highlighter: H_520, assignable_buckets: ['C']
# Highlighter: H_521, assignable_buckets: []
# Highlighter: H_522, assignable_buckets: ['A', 'C']
# Highlighter: H_523, assignable_buckets: ['C']
# Highlighter: H_524, assignable_buckets: ['C', 'D']
# Highlighter: H_525, assignable_buckets: ['A']
# Highlighter: H_526, assignable_buckets: ['A']
# Highlighter: H_527, assignable_buckets: ['C']
# Highlighter: H_528, assignable_buckets: ['B', 'C']
# Highlighter: H_529, assignable_buckets: []
# Highlighter: H_530, assignable_buckets: ['C', 'D']
# Highlighter: H_531, assignable_buckets: ['C']
# Highlighter: H_532, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_533, assignable_buckets: ['D']
# Highlighter: H_534, assignable_buckets: []
# Highlighter: H_535, assignable_buckets: ['D']
# Highlighter: H_536, assignable_buckets: []
# Highlighter: H_537, assignable_buckets: ['C']
# Highlighter: H_538, assignable_buckets: ['C', 'D']
# Highlighter: H_539, assignable_buckets: ['C', 'D']
# Highlighter: H_540, assignable_buckets: ['C']
# Highlighter: H_541, assignable_buckets: ['A', 'B', 'C', 'D']
# Highlighter: H_542, assignable_buckets: ['B', 'C']
# Highlighter: H_543, assignable_buckets: ['B', 'C']
# Highlighter: H_544, assignable_buckets: ['A']
# Highlighter: H_545, assignable_buckets: ['C', 'D']
# Highlighter: H_546, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_547, assignable_buckets: ['A', 'C']
# Highlighter: H_548, assignable_buckets: ['A', 'C']
# Highlighter: H_549, assignable_buckets: ['B', 'C']
# Highlighter: H_550, assignable_buckets: ['C', 'D']
# Highlighter: H_551, assignable_buckets: ['C', 'D']
# Highlighter: H_552, assignable_buckets: ['C']
# Highlighter: H_553, assignable_buckets: ['B', 'C']
# Highlighter: H_554, assignable_buckets: []
# Highlighter: H_555, assignable_buckets: ['C']
# Highlighter: H_556, assignable_buckets: ['C']
# Highlighter: H_557, assignable_buckets: ['A', 'C']
# Highlighter: H_558, assignable_buckets: ['C']
# Highlighter: H_559, assignable_buckets: []
# Highlighter: H_560, assignable_buckets: ['A', 'C', 'E']
# Highlighter: H_561, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_562, assignable_buckets: ['C']
# Highlighter: H_563, assignable_buckets: ['B', 'C']
# Highlighter: H_564, assignable_buckets: ['A']
# Highlighter: H_565, assignable_buckets: ['B', 'C', 'D', 'E']
# Highlighter: H_566, assignable_buckets: ['C', 'D']
# Highlighter: H_567, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_568, assignable_buckets: ['C', 'D']
# Highlighter: H_569, assignable_buckets: ['C']
# Highlighter: H_570, assignable_buckets: ['C', 'D']
# Highlighter: H_571, assignable_buckets: ['A', 'C', 'E']
# Highlighter: H_572, assignable_buckets: ['C', 'D']
# Highlighter: H_573, assignable_buckets: []
# Highlighter: H_574, assignable_buckets: ['C']
# Highlighter: H_575, assignable_buckets: ['A']
# Highlighter: H_576, assignable_buckets: ['B', 'C']
# Highlighter: H_577, assignable_buckets: ['C']
# Highlighter: H_578, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_579, assignable_buckets: ['B', 'C']
# Highlighter: H_580, assignable_buckets: ['A', 'C']
# Highlighter: H_581, assignable_buckets: ['B', 'C']
# Highlighter: H_582, assignable_buckets: ['B']
# Highlighter: H_583, assignable_buckets: ['B', 'C']
# Highlighter: H_584, assignable_buckets: ['A', 'B']
# Highlighter: H_585, assignable_buckets: ['C']
# Highlighter: H_586, assignable_buckets: ['A', 'C']
# Highlighter: H_587, assignable_buckets: ['C', 'D']
# Highlighter: H_588, assignable_buckets: ['A']
# Highlighter: H_589, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_590, assignable_buckets: ['C', 'D']
# Highlighter: H_591, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_592, assignable_buckets: ['C', 'D']
# Highlighter: H_593, assignable_buckets: ['C', 'D']
# Highlighter: H_594, assignable_buckets: ['C']
# Highlighter: H_595, assignable_buckets: ['C']
# Highlighter: H_596, assignable_buckets: []
# Highlighter: H_597, assignable_buckets: ['A']
# Highlighter: H_598, assignable_buckets: ['C']
# Highlighter: H_599, assignable_buckets: ['B', 'C']
# Highlighter: H_600, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_601, assignable_buckets: ['D']
# Highlighter: H_602, assignable_buckets: ['B', 'D']
# Highlighter: H_603, assignable_buckets: []
# Highlighter: H_604, assignable_buckets: ['B']
# Highlighter: H_605, assignable_buckets: ['C']
# Highlighter: H_606, assignable_buckets: ['A', 'B', 'C', 'D']
# Highlighter: H_607, assignable_buckets: ['A', 'C']
# Highlighter: H_608, assignable_buckets: ['D']
# Highlighter: H_609, assignable_buckets: []
# Highlighter: H_610, assignable_buckets: []
# Highlighter: H_611, assignable_buckets: ['A', 'C', 'D', 'E']
# Highlighter: H_612, assignable_buckets: ['A', 'B']
# Highlighter: H_613, assignable_buckets: ['C']
# Highlighter: H_614, assignable_buckets: ['D']
# Highlighter: H_615, assignable_buckets: ['B', 'C']
# Highlighter: H_616, assignable_buckets: ['B']
# Highlighter: H_617, assignable_buckets: ['D']
# Highlighter: H_618, assignable_buckets: ['C', 'D']
# Highlighter: H_619, assignable_buckets: []
# Highlighter: H_620, assignable_buckets: ['A']
# Highlighter: H_621, assignable_buckets: ['C']
# Highlighter: H_622, assignable_buckets: ['B', 'C']
# Highlighter: H_623, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_624, assignable_buckets: []
# Highlighter: H_625, assignable_buckets: ['C']
# Highlighter: H_626, assignable_buckets: ['A', 'B', 'D']
# Highlighter: H_627, assignable_buckets: ['B', 'C']
# Highlighter: H_628, assignable_buckets: ['C']
# Highlighter: H_629, assignable_buckets: ['B', 'C']
# Highlighter: H_630, assignable_buckets: ['C', 'D']
# Highlighter: H_631, assignable_buckets: ['C']
# Highlighter: H_632, assignable_buckets: []
# Highlighter: H_633, assignable_buckets: ['B', 'D']
# Highlighter: H_634, assignable_buckets: ['C', 'D', 'E']
# Highlighter: H_635, assignable_buckets: ['A']
# Highlighter: H_636, assignable_buckets: ['B', 'C']
# Highlighter: H_637, assignable_buckets: ['A', 'C', 'E']
# Highlighter: H_638, assignable_buckets: ['C']
# Highlighter: H_639, assignable_buckets: ['B']
# Highlighter: H_640, assignable_buckets: ['D']
# Highlighter: H_641, assignable_buckets: ['B', 'C']
# Highlighter: H_642, assignable_buckets: ['A']
# Highlighter: H_643, assignable_buckets: ['A', 'B']
# Highlighter: H_644, assignable_buckets: []
# Highlighter: H_645, assignable_buckets: ['B', 'C']
# Highlighter: H_646, assignable_buckets: ['C']
# Highlighter: H_647, assignable_buckets: ['A', 'C']
# Highlighter: H_648, assignable_buckets: []
# Highlighter: H_649, assignable_buckets: ['C', 'D']
# Highlighter: H_650, assignable_buckets: []
# Highlighter: H_651, assignable_buckets: ['B']
# Highlighter: H_652, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_653, assignable_buckets: ['C']
# Highlighter: H_654, assignable_buckets: []
# Highlighter: H_655, assignable_buckets: ['A', 'C']
# Highlighter: H_656, assignable_buckets: ['C']
# Highlighter: H_657, assignable_buckets: ['C']
# Highlighter: H_658, assignable_buckets: ['A', 'B', 'D']
# Highlighter: H_659, assignable_buckets: ['C']
# Highlighter: H_660, assignable_buckets: ['C', 'E']
# Highlighter: H_661, assignable_buckets: ['B', 'C', 'E']
# Highlighter: H_662, assignable_buckets: ['B', 'C']
# Highlighter: H_663, assignable_buckets: ['A', 'C']
# Highlighter: H_664, assignable_buckets: ['A', 'C']
# Highlighter: H_665, assignable_buckets: ['C']
# Highlighter: H_666, assignable_buckets: ['A', 'C']
# Highlighter: H_667, assignable_buckets: ['C']
# Highlighter: H_668, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_669, assignable_buckets: []
# Highlighter: H_670, assignable_buckets: ['B', 'C']
# Highlighter: H_671, assignable_buckets: ['A', 'C']
# Highlighter: H_672, assignable_buckets: ['A', 'D']
# Highlighter: H_673, assignable_buckets: ['A', 'C', 'E']
# Highlighter: H_674, assignable_buckets: ['B', 'C']
# Highlighter: H_675, assignable_buckets: ['D']
# Highlighter: H_676, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_677, assignable_buckets: []
# Highlighter: H_678, assignable_buckets: ['C']
# Highlighter: H_679, assignable_buckets: ['D']
# Highlighter: H_680, assignable_buckets: ['C']
# Highlighter: H_681, assignable_buckets: ['C']
# Highlighter: H_682, assignable_buckets: ['C']
# Highlighter: H_683, assignable_buckets: []
# Highlighter: H_684, assignable_buckets: ['C', 'D']
# Highlighter: H_685, assignable_buckets: ['B', 'D']
# Highlighter: H_686, assignable_buckets: []
# Highlighter: H_687, assignable_buckets: ['D']
# Highlighter: H_688, assignable_buckets: ['C', 'D']
# Highlighter: H_689, assignable_buckets: ['A', 'C']
# Highlighter: H_690, assignable_buckets: ['C', 'D']
# Highlighter: H_691, assignable_buckets: ['D']
# Highlighter: H_692, assignable_buckets: ['C']
# Highlighter: H_693, assignable_buckets: ['C']
# Highlighter: H_694, assignable_buckets: ['A', 'C']
# Highlighter: H_695, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_696, assignable_buckets: ['B', 'C', 'D', 'E']
# Highlighter: H_697, assignable_buckets: ['C']
# Highlighter: H_698, assignable_buckets: ['C']
# Highlighter: H_699, assignable_buckets: []
# Highlighter: H_700, assignable_buckets: ['A']
# Highlighter: H_701, assignable_buckets: ['C']
# Highlighter: H_702, assignable_buckets: ['C']
# Highlighter: H_703, assignable_buckets: ['E']
# Highlighter: H_704, assignable_buckets: ['C', 'D']
# Highlighter: H_705, assignable_buckets: ['C']
# Highlighter: H_706, assignable_buckets: ['C']
# Highlighter: H_707, assignable_buckets: []
# Highlighter: H_708, assignable_buckets: ['C']
# Highlighter: H_709, assignable_buckets: ['C']
# Highlighter: H_710, assignable_buckets: ['A', 'C']
# Highlighter: H_711, assignable_buckets: ['C']
# Highlighter: H_712, assignable_buckets: []
# Highlighter: H_713, assignable_buckets: ['D']
# Highlighter: H_714, assignable_buckets: ['C', 'D']
# Highlighter: H_715, assignable_buckets: ['A']
# Highlighter: H_716, assignable_buckets: ['D']
# Highlighter: H_717, assignable_buckets: ['E']
# Highlighter: H_718, assignable_buckets: ['A']
# Highlighter: H_719, assignable_buckets: ['A', 'C', 'D', 'E']
# Highlighter: H_720, assignable_buckets: ['C']
# Highlighter: H_721, assignable_buckets: ['C', 'D']
# Highlighter: H_722, assignable_buckets: ['A', 'D']
# Highlighter: H_723, assignable_buckets: ['D', 'E']
# Highlighter: H_724, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_725, assignable_buckets: ['C']
# Highlighter: H_726, assignable_buckets: ['A', 'B', 'C', 'E']
# Highlighter: H_727, assignable_buckets: ['C']
# Highlighter: H_728, assignable_buckets: ['C']
# Highlighter: H_729, assignable_buckets: ['A', 'B', 'C', 'E']
# Highlighter: H_730, assignable_buckets: ['B']
# Highlighter: H_731, assignable_buckets: ['B', 'D']
# Highlighter: H_732, assignable_buckets: ['C', 'D']
# Highlighter: H_733, assignable_buckets: ['A', 'B', 'C', 'D', 'E']
# Highlighter: H_734, assignable_buckets: ['A', 'D']
# Highlighter: H_735, assignable_buckets: []
# Highlighter: H_736, assignable_buckets: []
# Highlighter: H_737, assignable_buckets: ['C']
# Highlighter: H_738, assignable_buckets: ['C']
# Highlighter: H_739, assignable_buckets: ['B']
# Highlighter: H_740, assignable_buckets: []
# Highlighter: H_741, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_742, assignable_buckets: []
# Highlighter: H_743, assignable_buckets: ['A']
# Highlighter: H_744, assignable_buckets: ['C']
# Highlighter: H_745, assignable_buckets: []
# Highlighter: H_746, assignable_buckets: ['C']
# Highlighter: H_747, assignable_buckets: []
# Highlighter: H_748, assignable_buckets: ['C']
# Highlighter: H_749, assignable_buckets: ['B']
# Highlighter: H_750, assignable_buckets: []
# Highlighter: H_751, assignable_buckets: ['C', 'D']
# Highlighter: H_752, assignable_buckets: ['D']
# Highlighter: H_753, assignable_buckets: ['A', 'C']
# Highlighter: H_754, assignable_buckets: []
# Highlighter: H_755, assignable_buckets: ['E']
# Highlighter: H_756, assignable_buckets: ['C', 'D']
# Highlighter: H_757, assignable_buckets: ['C', 'D']
# Highlighter: H_758, assignable_buckets: ['A', 'C']
# Highlighter: H_759, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_760, assignable_buckets: ['D', 'E']
# Highlighter: H_761, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_762, assignable_buckets: ['C']
# Highlighter: H_763, assignable_buckets: ['A', 'B']
# Highlighter: H_764, assignable_buckets: ['D']
# Highlighter: H_765, assignable_buckets: []
# Highlighter: H_766, assignable_buckets: ['C']
# Highlighter: H_767, assignable_buckets: ['E']
# Highlighter: H_768, assignable_buckets: ['C']
# Highlighter: H_769, assignable_buckets: []
# Highlighter: H_770, assignable_buckets: []
# Highlighter: H_771, assignable_buckets: ['D']
# Highlighter: H_772, assignable_buckets: ['B']
# Highlighter: H_773, assignable_buckets: []
# Highlighter: H_774, assignable_buckets: ['D']
# Highlighter: H_775, assignable_buckets: ['C', 'D']
# Highlighter: H_776, assignable_buckets: ['A', 'C']
# Highlighter: H_777, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_778, assignable_buckets: ['C']
# Highlighter: H_779, assignable_buckets: ['B', 'C']
# Highlighter: H_780, assignable_buckets: ['C', 'D']
# Highlighter: H_781, assignable_buckets: ['A', 'D']
# Highlighter: H_782, assignable_buckets: ['B', 'C']
# Highlighter: H_783, assignable_buckets: ['D']
# Highlighter: H_784, assignable_buckets: []
# Highlighter: H_785, assignable_buckets: []
# Highlighter: H_786, assignable_buckets: []
# Highlighter: H_787, assignable_buckets: ['C']
# Highlighter: H_788, assignable_buckets: ['B', 'D']
# Highlighter: H_789, assignable_buckets: ['A', 'D']
# Highlighter: H_790, assignable_buckets: ['C']
# Highlighter: H_791, assignable_buckets: []
# Highlighter: H_792, assignable_buckets: ['D', 'E']
# Highlighter: H_793, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_794, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_795, assignable_buckets: ['C']
# Highlighter: H_796, assignable_buckets: ['C']
# Highlighter: H_797, assignable_buckets: ['A', 'D']
# Highlighter: H_798, assignable_buckets: ['C']
# Highlighter: H_799, assignable_buckets: ['D']
# Highlighter: H_800, assignable_buckets: ['C']
# Highlighter: H_801, assignable_buckets: ['A']
# Highlighter: H_802, assignable_buckets: ['C']
# Highlighter: H_803, assignable_buckets: []
# Highlighter: H_804, assignable_buckets: ['C']
# Highlighter: H_805, assignable_buckets: ['D']
# Highlighter: H_806, assignable_buckets: ['B', 'C']
# Highlighter: H_807, assignable_buckets: ['A', 'B', 'C', 'E']
# Highlighter: H_808, assignable_buckets: ['D']
# Highlighter: H_809, assignable_buckets: ['D']
# Highlighter: H_810, assignable_buckets: ['C']
# Highlighter: H_811, assignable_buckets: ['E']
# Highlighter: H_812, assignable_buckets: ['C']
# Highlighter: H_813, assignable_buckets: ['A', 'D']
# Highlighter: H_814, assignable_buckets: ['D']
# Highlighter: H_815, assignable_buckets: ['C']
# Highlighter: H_816, assignable_buckets: ['B', 'C']
# Highlighter: H_817, assignable_buckets: []
# Highlighter: H_818, assignable_buckets: ['B']
# Highlighter: H_819, assignable_buckets: ['C', 'D']
# Highlighter: H_820, assignable_buckets: ['B', 'C']
# Highlighter: H_821, assignable_buckets: ['B', 'C']
# Highlighter: H_822, assignable_buckets: ['C', 'E']
# Highlighter: H_823, assignable_buckets: ['C']
# Highlighter: H_824, assignable_buckets: ['C']
# Highlighter: H_825, assignable_buckets: []
# Highlighter: H_826, assignable_buckets: ['D']
# Highlighter: H_827, assignable_buckets: ['D']
# Highlighter: H_828, assignable_buckets: ['C', 'D']
# Highlighter: H_829, assignable_buckets: ['C']
# Highlighter: H_830, assignable_buckets: ['C']
# Highlighter: H_831, assignable_buckets: ['B', 'C']
# Highlighter: H_832, assignable_buckets: ['A', 'D']
# Highlighter: H_833, assignable_buckets: ['D']
# Highlighter: H_834, assignable_buckets: ['B']
# Highlighter: H_835, assignable_buckets: ['C']
# Highlighter: H_836, assignable_buckets: ['C']
# Highlighter: H_837, assignable_buckets: ['C', 'D']
# Highlighter: H_838, assignable_buckets: ['C', 'E']
# Highlighter: H_839, assignable_buckets: ['C', 'E']
# Highlighter: H_840, assignable_buckets: ['B', 'C']
# Highlighter: H_841, assignable_buckets: []
# Highlighter: H_842, assignable_buckets: []
# Highlighter: H_843, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_844, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_845, assignable_buckets: ['A', 'C']
# Highlighter: H_846, assignable_buckets: []
# Highlighter: H_847, assignable_buckets: ['A']
# Highlighter: H_848, assignable_buckets: ['C', 'D', 'E']
# Highlighter: H_849, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_850, assignable_buckets: ['C', 'D']
# Highlighter: H_851, assignable_buckets: ['B', 'C']
# Highlighter: H_852, assignable_buckets: ['C']
# Highlighter: H_853, assignable_buckets: ['B', 'D']
# Highlighter: H_854, assignable_buckets: ['B']
# Highlighter: H_855, assignable_buckets: []
# Highlighter: H_856, assignable_buckets: []
# Highlighter: H_857, assignable_buckets: ['C']
# Highlighter: H_858, assignable_buckets: ['C', 'D']
# Highlighter: H_859, assignable_buckets: ['C']
# Highlighter: H_860, assignable_buckets: ['C']
# Highlighter: H_861, assignable_buckets: ['B']
# Highlighter: H_862, assignable_buckets: ['B', 'C']
# Highlighter: H_863, assignable_buckets: []
# Highlighter: H_864, assignable_buckets: ['C', 'D']
# Highlighter: H_865, assignable_buckets: []
# Highlighter: H_866, assignable_buckets: ['C', 'D']
# Highlighter: H_867, assignable_buckets: ['B']
# Highlighter: H_868, assignable_buckets: ['A']
# Highlighter: H_869, assignable_buckets: ['C', 'E']
# Highlighter: H_870, assignable_buckets: ['B']
# Highlighter: H_871, assignable_buckets: ['C', 'D']
# Highlighter: H_872, assignable_buckets: []
# Highlighter: H_873, assignable_buckets: ['B']
# Highlighter: H_874, assignable_buckets: ['C']
# Highlighter: H_875, assignable_buckets: ['C']
# Highlighter: H_876, assignable_buckets: ['D']
# Highlighter: H_877, assignable_buckets: ['A', 'C']
# Highlighter: H_878, assignable_buckets: ['C']
# Highlighter: H_879, assignable_buckets: []
# Highlighter: H_880, assignable_buckets: ['C']
# Highlighter: H_881, assignable_buckets: ['A', 'D']
# Highlighter: H_882, assignable_buckets: []
# Highlighter: H_883, assignable_buckets: ['A', 'B', 'C', 'E']
# Highlighter: H_884, assignable_buckets: ['A', 'C']
# Highlighter: H_885, assignable_buckets: ['A', 'C']
# Highlighter: H_886, assignable_buckets: ['C']
# Highlighter: H_887, assignable_buckets: ['A', 'C']
# Highlighter: H_888, assignable_buckets: ['A', 'B']
# Highlighter: H_889, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_890, assignable_buckets: ['A', 'B', 'C', 'D']
# Highlighter: H_891, assignable_buckets: ['C', 'D']
# Highlighter: H_892, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_893, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_894, assignable_buckets: ['C', 'D']
# Highlighter: H_895, assignable_buckets: ['A', 'C']
# Highlighter: H_896, assignable_buckets: ['C']
# Highlighter: H_897, assignable_buckets: ['A', 'D']
# Highlighter: H_898, assignable_buckets: ['C', 'D']
# Highlighter: H_899, assignable_buckets: ['B', 'C', 'D', 'E']
# Highlighter: H_900, assignable_buckets: ['C', 'D']
# Highlighter: H_901, assignable_buckets: ['C']
# Highlighter: H_902, assignable_buckets: ['A', 'E']
# Highlighter: H_903, assignable_buckets: ['B', 'C', 'D', 'E']
# Highlighter: H_904, assignable_buckets: []
# Highlighter: H_905, assignable_buckets: []
# Highlighter: H_906, assignable_buckets: []
# Highlighter: H_907, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_908, assignable_buckets: ['C']
# Highlighter: H_909, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_910, assignable_buckets: ['A', 'C']
# Highlighter: H_911, assignable_buckets: ['C']
# Highlighter: H_912, assignable_buckets: ['A', 'C']
# Highlighter: H_913, assignable_buckets: ['C', 'D']
# Highlighter: H_914, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_915, assignable_buckets: ['D']
# Highlighter: H_916, assignable_buckets: ['B', 'C']
# Highlighter: H_917, assignable_buckets: ['A']
# Highlighter: H_918, assignable_buckets: ['C', 'D']
# Highlighter: H_919, assignable_buckets: ['C']
# Highlighter: H_920, assignable_buckets: ['D']
# Highlighter: H_921, assignable_buckets: ['A', 'B', 'C', 'D', 'E']
# Highlighter: H_922, assignable_buckets: ['A', 'C']
# Highlighter: H_923, assignable_buckets: ['D']
# Highlighter: H_924, assignable_buckets: ['A']
# Highlighter: H_925, assignable_buckets: ['C']
# Highlighter: H_926, assignable_buckets: ['C', 'D', 'E']
# Highlighter: H_927, assignable_buckets: ['C']
# Highlighter: H_928, assignable_buckets: []
# Highlighter: H_929, assignable_buckets: ['B']
# Highlighter: H_930, assignable_buckets: ['C']
# Highlighter: H_931, assignable_buckets: ['B', 'C']
# Highlighter: H_932, assignable_buckets: ['C']
# Highlighter: H_933, assignable_buckets: ['C', 'D']
# Highlighter: H_934, assignable_buckets: ['A', 'C', 'E']
# Highlighter: H_935, assignable_buckets: ['B', 'C']
# Highlighter: H_936, assignable_buckets: ['A', 'C']
# Highlighter: H_937, assignable_buckets: ['B', 'C']
# Highlighter: H_938, assignable_buckets: ['C']
# Highlighter: H_939, assignable_buckets: ['C']
# Highlighter: H_940, assignable_buckets: ['C']
# Highlighter: H_941, assignable_buckets: []
# Highlighter: H_942, assignable_buckets: ['A', 'C', 'E']
# Highlighter: H_943, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_944, assignable_buckets: ['B', 'C']
# Highlighter: H_945, assignable_buckets: ['A', 'C']
# Highlighter: H_946, assignable_buckets: []
# Highlighter: H_947, assignable_buckets: ['C']
# Highlighter: H_948, assignable_buckets: []
# Highlighter: H_949, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_950, assignable_buckets: ['C']
# Highlighter: H_951, assignable_buckets: []
# Highlighter: H_952, assignable_buckets: ['B']
# Highlighter: H_953, assignable_buckets: ['C', 'D']
# Highlighter: H_954, assignable_buckets: ['C', 'D']
# Highlighter: H_955, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_956, assignable_buckets: ['C']
# Highlighter: H_957, assignable_buckets: ['C']
# Highlighter: H_958, assignable_buckets: ['A']
# Highlighter: H_959, assignable_buckets: ['C', 'E']
# Highlighter: H_960, assignable_buckets: ['C']
# Highlighter: H_961, assignable_buckets: ['B', 'C']
# Highlighter: H_962, assignable_buckets: []
# Highlighter: H_963, assignable_buckets: ['B']
# Highlighter: H_964, assignable_buckets: ['C']
# Highlighter: H_965, assignable_buckets: ['B', 'C']
# Highlighter: H_966, assignable_buckets: ['C', 'D']
# Highlighter: H_967, assignable_buckets: ['C']
# Highlighter: H_968, assignable_buckets: ['C', 'E']
# Highlighter: H_969, assignable_buckets: ['C']
# Highlighter: H_970, assignable_buckets: ['B']
# Highlighter: H_971, assignable_buckets: ['B', 'D']
# Highlighter: H_972, assignable_buckets: ['C', 'E']
# Highlighter: H_973, assignable_buckets: ['C']
# Highlighter: H_974, assignable_buckets: ['C', 'E']
# Highlighter: H_975, assignable_buckets: ['C', 'D']
# Highlighter: H_976, assignable_buckets: ['C']
# Highlighter: H_977, assignable_buckets: ['B', 'C']
# Highlighter: H_978, assignable_buckets: ['C']
# Highlighter: H_979, assignable_buckets: ['C']
# Highlighter: H_980, assignable_buckets: ['C']
# Highlighter: H_981, assignable_buckets: ['C']
# Highlighter: H_982, assignable_buckets: ['C']
# Highlighter: H_983, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_984, assignable_buckets: ['C']
# Highlighter: H_985, assignable_buckets: ['D']
# Highlighter: H_986, assignable_buckets: []
# Highlighter: H_987, assignable_buckets: ['B', 'E']
# Highlighter: H_988, assignable_buckets: ['D']
# Highlighter: H_989, assignable_buckets: []
# Highlighter: H_990, assignable_buckets: ['B']
# ...
# Highlighter: H_9678, assignable_buckets: ['D']
# Highlighter: H_9679, assignable_buckets: ['C']
# Highlighter: H_9680, assignable_buckets: ['C']
# Highlighter: H_9681, assignable_buckets: ['D']
# Highlighter: H_9682, assignable_buckets: ['C']
# Highlighter: H_9683, assignable_buckets: ['C', 'D']
# Highlighter: H_9684, assignable_buckets: ['A']
# Highlighter: H_9685, assignable_buckets: ['C']
# Highlighter: H_9686, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_9687, assignable_buckets: ['C']
# Highlighter: H_9688, assignable_buckets: ['C', 'D']
# Highlighter: H_9689, assignable_buckets: []
# Highlighter: H_9690, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_9691, assignable_buckets: ['B', 'D']
# Highlighter: H_9692, assignable_buckets: ['D']
# Highlighter: H_9693, assignable_buckets: ['B']
# Highlighter: H_9694, assignable_buckets: ['A']
# Highlighter: H_9695, assignable_buckets: ['C', 'D', 'E']
# Highlighter: H_9696, assignable_buckets: ['B', 'C', 'E']
# Highlighter: H_9697, assignable_buckets: ['A', 'B', 'C', 'E']
# Highlighter: H_9698, assignable_buckets: ['A', 'C']
# Highlighter: H_9699, assignable_buckets: ['C']
# Highlighter: H_9700, assignable_buckets: ['C']
# Highlighter: H_9701, assignable_buckets: ['C']
# Highlighter: H_9702, assignable_buckets: ['A', 'B', 'D']
# Highlighter: H_9703, assignable_buckets: []
# Highlighter: H_9704, assignable_buckets: ['A', 'C']
# Highlighter: H_9705, assignable_buckets: ['C']
# Highlighter: H_9706, assignable_buckets: ['C', 'D']
# Highlighter: H_9707, assignable_buckets: ['D']
# Highlighter: H_9708, assignable_buckets: []
# Highlighter: H_9709, assignable_buckets: ['D']
# Highlighter: H_9710, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_9711, assignable_buckets: ['B', 'C']
# Highlighter: H_9712, assignable_buckets: ['B', 'C']
# Highlighter: H_9713, assignable_buckets: ['A', 'C']
# Highlighter: H_9714, assignable_buckets: []
# Highlighter: H_9715, assignable_buckets: ['B']
# Highlighter: H_9716, assignable_buckets: ['C']
# Highlighter: H_9717, assignable_buckets: ['A', 'C']
# Highlighter: H_9718, assignable_buckets: ['B', 'C']
# Highlighter: H_9719, assignable_buckets: ['A']
# Highlighter: H_9720, assignable_buckets: ['E']
# Highlighter: H_9721, assignable_buckets: ['C']
# Highlighter: H_9722, assignable_buckets: ['C']
# Highlighter: H_9723, assignable_buckets: ['A', 'C']
# Highlighter: H_9724, assignable_buckets: ['C']
# Highlighter: H_9725, assignable_buckets: ['B', 'C']
# Highlighter: H_9726, assignable_buckets: ['B', 'C']
# Highlighter: H_9727, assignable_buckets: []
# Highlighter: H_9728, assignable_buckets: ['A', 'C']
# Highlighter: H_9729, assignable_buckets: ['A', 'B']
# Highlighter: H_9730, assignable_buckets: ['A', 'C']
# Highlighter: H_9731, assignable_buckets: ['B', 'C']
# Highlighter: H_9732, assignable_buckets: ['B']
# Highlighter: H_9733, assignable_buckets: []
# Highlighter: H_9734, assignable_buckets: ['B', 'C']
# Highlighter: H_9735, assignable_buckets: ['A', 'C', 'E']
# Highlighter: H_9736, assignable_buckets: ['B']
# Highlighter: H_9737, assignable_buckets: ['C']
# Highlighter: H_9738, assignable_buckets: ['C']
# Highlighter: H_9739, assignable_buckets: ['B', 'C']
# Highlighter: H_9740, assignable_buckets: []
# Highlighter: H_9741, assignable_buckets: ['C']
# Highlighter: H_9742, assignable_buckets: ['A', 'C', 'E']
# Highlighter: H_9743, assignable_buckets: ['A', 'D']
# Highlighter: H_9744, assignable_buckets: ['B', 'D']
# Highlighter: H_9745, assignable_buckets: ['A']
# Highlighter: H_9746, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_9747, assignable_buckets: ['C', 'D']
# Highlighter: H_9748, assignable_buckets: ['D']
# Highlighter: H_9749, assignable_buckets: ['C', 'D']
# Highlighter: H_9750, assignable_buckets: ['C']
# Highlighter: H_9751, assignable_buckets: ['C']
# Highlighter: H_9752, assignable_buckets: ['C', 'D']
# Highlighter: H_9753, assignable_buckets: []
# Highlighter: H_9754, assignable_buckets: ['C']
# Highlighter: H_9755, assignable_buckets: ['A', 'C', 'E']
# Highlighter: H_9756, assignable_buckets: ['A', 'D']
# Highlighter: H_9757, assignable_buckets: []
# Highlighter: H_9758, assignable_buckets: []
# Highlighter: H_9759, assignable_buckets: ['B', 'C']
# Highlighter: H_9760, assignable_buckets: ['C']
# Highlighter: H_9761, assignable_buckets: ['B', 'C']
# Highlighter: H_9762, assignable_buckets: []
# Highlighter: H_9763, assignable_buckets: ['A', 'C', 'E']
# Highlighter: H_9764, assignable_buckets: ['C', 'E']
# Highlighter: H_9765, assignable_buckets: ['B']
# Highlighter: H_9766, assignable_buckets: ['C']
# Highlighter: H_9767, assignable_buckets: []
# Highlighter: H_9768, assignable_buckets: ['C', 'D']
# Highlighter: H_9769, assignable_buckets: ['A']
# Highlighter: H_9770, assignable_buckets: ['D']
# Highlighter: H_9771, assignable_buckets: ['B', 'E']
# Highlighter: H_9772, assignable_buckets: ['C', 'D']
# Highlighter: H_9773, assignable_buckets: ['C']
# Highlighter: H_9774, assignable_buckets: []
# Highlighter: H_9775, assignable_buckets: ['C']
# Highlighter: H_9776, assignable_buckets: ['A']
# Highlighter: H_9777, assignable_buckets: ['B', 'C']
# Highlighter: H_9778, assignable_buckets: ['C']
# Highlighter: H_9779, assignable_buckets: []
# Highlighter: H_9780, assignable_buckets: ['B', 'C']
# Highlighter: H_9781, assignable_buckets: ['D']
# Highlighter: H_9782, assignable_buckets: ['C']
# Highlighter: H_9783, assignable_buckets: ['A', 'B', 'D']
# Highlighter: H_9784, assignable_buckets: ['A', 'B']
# Highlighter: H_9785, assignable_buckets: ['A', 'B']
# Highlighter: H_9786, assignable_buckets: ['C']
# Highlighter: H_9787, assignable_buckets: ['C']
# Highlighter: H_9788, assignable_buckets: ['B']
# Highlighter: H_9789, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_9790, assignable_buckets: ['B']
# Highlighter: H_9791, assignable_buckets: []
# Highlighter: H_9792, assignable_buckets: ['C']
# Highlighter: H_9793, assignable_buckets: ['D']
# Highlighter: H_9794, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_9795, assignable_buckets: ['C', 'D']
# Highlighter: H_9796, assignable_buckets: ['A']
# Highlighter: H_9797, assignable_buckets: []
# Highlighter: H_9798, assignable_buckets: ['C', 'D', 'E']
# Highlighter: H_9799, assignable_buckets: ['C', 'D']
# Highlighter: H_9800, assignable_buckets: ['C']
# Highlighter: H_9801, assignable_buckets: []
# Highlighter: H_9802, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_9803, assignable_buckets: ['A', 'D']
# Highlighter: H_9804, assignable_buckets: ['C']
# Highlighter: H_9805, assignable_buckets: ['A', 'C']
# Highlighter: H_9806, assignable_buckets: ['C']
# Highlighter: H_9807, assignable_buckets: ['C']
# Highlighter: H_9808, assignable_buckets: []
# Highlighter: H_9809, assignable_buckets: ['C']
# Highlighter: H_9810, assignable_buckets: ['C']
# Highlighter: H_9811, assignable_buckets: ['D']
# Highlighter: H_9812, assignable_buckets: ['A', 'B', 'C', 'D']
# Highlighter: H_9813, assignable_buckets: ['C']
# Highlighter: H_9814, assignable_buckets: ['C']
# Highlighter: H_9815, assignable_buckets: []
# Highlighter: H_9816, assignable_buckets: ['C']
# Highlighter: H_9817, assignable_buckets: ['C']
# Highlighter: H_9818, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_9819, assignable_buckets: ['A']
# Highlighter: H_9820, assignable_buckets: ['C']
# Highlighter: H_9821, assignable_buckets: ['A', 'B', 'C', 'D']
# Highlighter: H_9822, assignable_buckets: ['D']
# Highlighter: H_9823, assignable_buckets: ['D']
# Highlighter: H_9824, assignable_buckets: ['C', 'D']
# Highlighter: H_9825, assignable_buckets: ['A', 'C']
# Highlighter: H_9826, assignable_buckets: ['B', 'C']
# Highlighter: H_9827, assignable_buckets: ['A', 'C']
# Highlighter: H_9828, assignable_buckets: ['B']
# Highlighter: H_9829, assignable_buckets: []
# Highlighter: H_9830, assignable_buckets: ['A', 'C', 'E']
# Highlighter: H_9831, assignable_buckets: ['C']
# Highlighter: H_9832, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_9833, assignable_buckets: ['B']
# Highlighter: H_9834, assignable_buckets: ['B', 'C', 'D', 'E']
# Highlighter: H_9835, assignable_buckets: ['C', 'E']
# Highlighter: H_9836, assignable_buckets: ['A', 'C']
# Highlighter: H_9837, assignable_buckets: ['A']
# Highlighter: H_9838, assignable_buckets: ['D']
# Highlighter: H_9839, assignable_buckets: ['A', 'C']
# Highlighter: H_9840, assignable_buckets: ['E']
# Highlighter: H_9841, assignable_buckets: ['C']
# Highlighter: H_9842, assignable_buckets: ['A', 'C']
# Highlighter: H_9843, assignable_buckets: ['C']
# Highlighter: H_9844, assignable_buckets: ['C']
# Highlighter: H_9845, assignable_buckets: ['B', 'C']
# Highlighter: H_9846, assignable_buckets: ['D']
# Highlighter: H_9847, assignable_buckets: ['A', 'B', 'D', 'E']
# Highlighter: H_9848, assignable_buckets: ['C']
# Highlighter: H_9849, assignable_buckets: []
# Highlighter: H_9850, assignable_buckets: []
# Highlighter: H_9851, assignable_buckets: ['A']
# Highlighter: H_9852, assignable_buckets: ['C']
# Highlighter: H_9853, assignable_buckets: ['A', 'B', 'C', 'D']
# Highlighter: H_9854, assignable_buckets: ['C', 'D']
# Highlighter: H_9855, assignable_buckets: ['A', 'B', 'C', 'D']
# Highlighter: H_9856, assignable_buckets: ['B']
# Highlighter: H_9857, assignable_buckets: ['C', 'D']
# Highlighter: H_9858, assignable_buckets: []
# Highlighter: H_9859, assignable_buckets: ['A', 'D']
# Highlighter: H_9860, assignable_buckets: ['B', 'D']
# Highlighter: H_9861, assignable_buckets: ['D']
# Highlighter: H_9862, assignable_buckets: ['C', 'D']
# Highlighter: H_9863, assignable_buckets: ['A', 'C']
# Highlighter: H_9864, assignable_buckets: ['E']
# Highlighter: H_9865, assignable_buckets: ['C']
# Highlighter: H_9866, assignable_buckets: []
# Highlighter: H_9867, assignable_buckets: ['C']
# Highlighter: H_9868, assignable_buckets: ['B']
# Highlighter: H_9869, assignable_buckets: []
# Highlighter: H_9870, assignable_buckets: ['C']
# Highlighter: H_9871, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_9872, assignable_buckets: []
# Highlighter: H_9873, assignable_buckets: ['C', 'D']
# Highlighter: H_9874, assignable_buckets: []
# Highlighter: H_9875, assignable_buckets: ['C']
# Highlighter: H_9876, assignable_buckets: ['B', 'C']
# Highlighter: H_9877, assignable_buckets: []
# Highlighter: H_9878, assignable_buckets: ['B', 'C']
# Highlighter: H_9879, assignable_buckets: ['C']
# Highlighter: H_9880, assignable_buckets: ['C', 'D']
# Highlighter: H_9881, assignable_buckets: ['B', 'D']
# Highlighter: H_9882, assignable_buckets: ['A', 'C']
# Highlighter: H_9883, assignable_buckets: ['E']
# Highlighter: H_9884, assignable_buckets: ['C']
# Highlighter: H_9885, assignable_buckets: ['A', 'B', 'C', 'D']
# Highlighter: H_9886, assignable_buckets: ['D']
# Highlighter: H_9887, assignable_buckets: ['B']
# Highlighter: H_9888, assignable_buckets: ['C']
# Highlighter: H_9889, assignable_buckets: []
# Highlighter: H_9890, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_9891, assignable_buckets: []
# Highlighter: H_9892, assignable_buckets: []
# Highlighter: H_9893, assignable_buckets: ['A', 'C']
# Highlighter: H_9894, assignable_buckets: ['C', 'D']
# Highlighter: H_9895, assignable_buckets: ['B', 'C']
# Highlighter: H_9896, assignable_buckets: ['A', 'C']
# Highlighter: H_9897, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_9898, assignable_buckets: ['B', 'D']
# Highlighter: H_9899, assignable_buckets: ['C', 'D']
# Highlighter: H_9900, assignable_buckets: ['C']
# Highlighter: H_9901, assignable_buckets: []
# Highlighter: H_9902, assignable_buckets: ['C']
# Highlighter: H_9903, assignable_buckets: ['C', 'E']
# Highlighter: H_9904, assignable_buckets: ['C', 'D']
# Highlighter: H_9905, assignable_buckets: ['A', 'C']
# Highlighter: H_9906, assignable_buckets: ['E']
# Highlighter: H_9907, assignable_buckets: ['C', 'E']
# Highlighter: H_9908, assignable_buckets: []
# Highlighter: H_9909, assignable_buckets: ['C']
# Highlighter: H_9910, assignable_buckets: []
# Highlighter: H_9911, assignable_buckets: []
# Highlighter: H_9912, assignable_buckets: ['B', 'C']
# Highlighter: H_9913, assignable_buckets: []
# Highlighter: H_9914, assignable_buckets: ['C', 'D']
# Highlighter: H_9915, assignable_buckets: ['B', 'C']
# Highlighter: H_9916, assignable_buckets: ['A']
# Highlighter: H_9917, assignable_buckets: ['C', 'D']
# Highlighter: H_9918, assignable_buckets: []
# Highlighter: H_9919, assignable_buckets: ['D']
# Highlighter: H_9920, assignable_buckets: ['B', 'C']
# Highlighter: H_9921, assignable_buckets: ['D']
# Highlighter: H_9922, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_9923, assignable_buckets: []
# Highlighter: H_9924, assignable_buckets: ['C']
# Highlighter: H_9925, assignable_buckets: ['D']
# Highlighter: H_9926, assignable_buckets: ['B', 'C']
# Highlighter: H_9927, assignable_buckets: ['C']
# Highlighter: H_9928, assignable_buckets: ['A', 'C']
# Highlighter: H_9929, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_9930, assignable_buckets: []
# Highlighter: H_9931, assignable_buckets: ['C', 'D']
# Highlighter: H_9932, assignable_buckets: []
# Highlighter: H_9933, assignable_buckets: ['B']
# Highlighter: H_9934, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_9935, assignable_buckets: []
# Highlighter: H_9936, assignable_buckets: ['C', 'D']
# Highlighter: H_9937, assignable_buckets: ['A', 'B', 'C']
# Highlighter: H_9938, assignable_buckets: ['A', 'C']
# Highlighter: H_9939, assignable_buckets: []
# Highlighter: H_9940, assignable_buckets: ['A', 'C']
# Highlighter: H_9941, assignable_buckets: ['C', 'D']
# Highlighter: H_9942, assignable_buckets: []
# Highlighter: H_9943, assignable_buckets: []
# Highlighter: H_9944, assignable_buckets: ['A', 'C', 'E']
# Highlighter: H_9945, assignable_buckets: ['C']
# Highlighter: H_9946, assignable_buckets: ['C']
# Highlighter: H_9947, assignable_buckets: ['A', 'C', 'D']
# Highlighter: H_9948, assignable_buckets: ['B', 'C']
# Highlighter: H_9949, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_9950, assignable_buckets: ['B', 'E']
# Highlighter: H_9951, assignable_buckets: ['A', 'D']
# Highlighter: H_9952, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_9953, assignable_buckets: ['C']
# Highlighter: H_9954, assignable_buckets: []
# Highlighter: H_9955, assignable_buckets: ['B', 'C', 'E']
# Highlighter: H_9956, assignable_buckets: []
# Highlighter: H_9957, assignable_buckets: ['C']
# Highlighter: H_9958, assignable_buckets: []
# Highlighter: H_9959, assignable_buckets: ['B']
# Highlighter: H_9960, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_9961, assignable_buckets: ['D']
# Highlighter: H_9962, assignable_buckets: ['C', 'D']
# Highlighter: H_9963, assignable_buckets: ['C']
# Highlighter: H_9964, assignable_buckets: []
# Highlighter: H_9965, assignable_buckets: ['B', 'C', 'D']
# Highlighter: H_9966, assignable_buckets: ['D']
# Highlighter: H_9967, assignable_buckets: ['C']
# Highlighter: H_9968, assignable_buckets: []
# Highlighter: H_9969, assignable_buckets: ['D', 'E']
# Highlighter: H_9970, assignable_buckets: ['C']
# Highlighter: H_9971, assignable_buckets: ['B', 'D']
# Highlighter: H_9972, assignable_buckets: ['C', 'D']
# Highlighter: H_9973, assignable_buckets: []
# Highlighter: H_9974, assignable_buckets: ['A', 'C']
# Highlighter: H_9975, assignable_buckets: ['C', 'D']
# Highlighter: H_9976, assignable_buckets: ['A', 'D']
# Highlighter: H_9977, assignable_buckets: ['A', 'D']
# Highlighter: H_9978, assignable_buckets: ['B', 'C']
# Highlighter: H_9979, assignable_buckets: []
# Highlighter: H_9980, assignable_buckets: ['C', 'D', 'E']
# Highlighter: H_9981, assignable_buckets: []
# Highlighter: H_9982, assignable_buckets: ['B']
# Highlighter: H_9983, assignable_buckets: ['A', 'B', 'C', 'D']
# Highlighter: H_9984, assignable_buckets: ['C']
# Highlighter: H_9985, assignable_buckets: ['C']
# Highlighter: H_9986, assignable_buckets: ['A', 'C', 'E']
# Highlighter: H_9987, assignable_buckets: ['D']
# Highlighter: H_9988, assignable_buckets: ['C']
# Highlighter: H_9989, assignable_buckets: ['B']
# Highlighter: H_9990, assignable_buckets: ['A', 'C']
# Highlighter: H_9991, assignable_buckets: ['C']
# Highlighter: H_9992, assignable_buckets: ['C', 'D']
# Highlighter: H_9993, assignable_buckets: ['B']
# Highlighter: H_9994, assignable_buckets: ['C', 'D']
# Highlighter: H_9995, assignable_buckets: ['B']
# Highlighter: H_9996, assignable_buckets: ['C']
# Highlighter: H_9997, assignable_buckets: ['B', 'E']
# Highlighter: H_9998, assignable_buckets: ['C', 'E']
# Highlighter: H_9999, assignable_buckets: ['C']

# %% [markdown]
# ## Visualizing the Buckets

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a graph
G = nx.Graph()

# Add highlighters as nodes
for highlighter in highlighters:
    G.add_node(highlighter.name, type='highlighter')

bucket_colors = {}
for bucket in buckets:
    color = (random.random(), random.random(), random.random())  # Random RGB color
    bucket_colors[bucket.name] = color
    G.add_node(bucket.name, type='bucket', color=color)
    for highlighter in highlighters:
        if bucket.name in highlighter.assignable_buckets:
            G.add_edge(highlighter.name, bucket.name)

# Draw the graph
# pos = nx.spring_layout(G)
# pos = nx.circular_layout(G)
# pos = nx.spectral_layout(G)
pos = nx.kamada_kawai_layout(G)

node_types = nx.get_node_attributes(G, 'type')
node_sizes = [500 if node_types[node] == 'bucket' else 10 for node in G.nodes]  # Larger size for buckets

node_colors = [bucket_colors[node] if node_types[node] == 'bucket' else 'blue' for node in G.nodes]

nx.draw(G, pos, with_labels=False, node_color=node_colors, node_size=node_sizes)
plt.show()

# %% [markdown]
# ## Defining a Fitness Function
#
# Our fitness function needs to somewhat accurately define what a "good" assignment is.
#
# "Good" means:
# - High percentage of filled buckets

# %%
import statistics 

# Fitness function that just optimizes for
# total percentage of assigned Highlighters
def fitness_1(buckets, assignment):
    '''
        buckets: []Bucket
        assignments: dict {Highlighter: Bucket_Name}

    '''

    assigned_buckets = list(assignment.values())

    fill_ratios = []
    for bucket in buckets:
        num_filled = sum(1 for assigned_bucket in assigned_buckets if assigned_bucket == bucket.name)
        fill_ratios.append(min(num_filled / bucket.fill_goal, 1.0))

    return statistics.mean(fill_ratios)

# Same as fitness_1 except it penalizes for overfilling buckets
def fitness_2(buckets, assignment):
    '''
        buckets: []Bucket
        assignments: dict {Highlighter: Bucket_Name}
    '''

    assigned_buckets = list(assignment.values())

    fill_ratios = []
    for bucket in buckets:
        num_filled = sum(1 for assigned_bucket in assigned_buckets if assigned_bucket == bucket.name)
        fill_ratio = num_filled / bucket.fill_goal
        if fill_ratio > 1.0:
            # Apply penalty for fill ratios greater than 1
            penalty = 1.0 - (fill_ratio - 1.0)
            fill_ratios.append(penalty)
        else:
            fill_ratios.append(fill_ratio)

    return statistics.mean(fill_ratios)



def fitness_3(buckets, assignments):
    """
    Calculate the fitness score based on the total number of assigned highlighters divided by the sum of bucket fill goals.
    
    :param buckets: List of Bucket objects
    :param assignments: Dictionary mapping Highlighter objects to bucket names
    :return: Fitness score
    """
    total_assigned_highlighters = len(assignments)
    total_fill_goals = sum(bucket.fill_goal for bucket in buckets)
    
    # Avoid division by zero
    if total_fill_goals == 0:
        return 0.0
    
    # Calculate fitness score
    fitness_score = total_assigned_highlighters / total_fill_goals
    
    return fitness_score

# %% [markdown]
# ## Assignment Generation

# %% [markdown]
# ### Random

# %%
import random
def generate_random_assignment(buckets, highlighters):
    '''
        Each Highlighter can only be assigned to 1 Bucket.
    '''
    assignment = {}
    for h in highlighters:
        # Randomly choose one of the highlighter's assignable buckets
        chosen_bucket = random.choice(h.assignable_buckets)
        assignment[h] = chosen_bucket
    return assignment

assignment = generate_random_assignment(buckets, highlighters)

# %% [markdown]
# ### Weighted Random Assignment - Prioritizes Fill Needs

# %%
import random

def generate_weighted_assignment(buckets, highlighters):
    '''
        Generate assignments based on Bucket needs with some degree of randomness.
        Each Highlighter can only be assigned to one of its assignable buckets.
    '''
    assignment = {}
    
    # Dictionary to keep track of total filled per bucket
    filled_per_bucket = {bucket.name: 0 for bucket in buckets}
    
    # Calculate total filled per bucket
    for h in highlighters:
        if h in assignment:
            filled_per_bucket[assignment[h]] += 1

    random.shuffle(highlighters)
    for h in highlighters:
        # Filter buckets to only include those that are assignable to the highlighter
        assignable_buckets = [bucket for bucket in buckets if bucket.name in h.assignable_buckets]

        # If there are no assignable buckets, skip assignment for this highlighter
        if not assignable_buckets:
            continue
        
        # Calculate remaining needs ratios for each bucket
        remaining_ratios = [(bucket.fill_goal - filled_per_bucket[bucket.name]) / bucket.fill_goal for bucket in assignable_buckets]
        
        # Calculate weights based on remaining needs ratios
        weights = remaining_ratios
        
        # Calculate cumulative weights
        cumulative_weights = [sum(weights[:i+1]) for i in range(len(weights))]
        
        # Choose a random number within the total weight
        rand_num = random.uniform(0, sum(weights))
        
        # Find the corresponding bucket based on the random number
        chosen_bucket = None
        for i, cum_weight in enumerate(cumulative_weights):
            if rand_num <= cum_weight:
                chosen_bucket = assignable_buckets[i]
                break
        if chosen_bucket:
            assignment[h] = chosen_bucket.name
        
            # Update total filled per bucket
            filled_per_bucket[chosen_bucket.name] += 1
        else:
            assignment[h] = ''
    return assignment

assignment = generate_weighted_assignment(buckets, highlighters)

# %% [markdown]
# ## Visualize the Assignment

# %%
import matplotlib.pyplot as plt

def generate_bar_graphs(buckets, assignment):
    # Initialize lists to store fill goals and total filled for each bucket
    fill_goals = []
    total_filled = []

    # Iterate over each bucket to gather fill goals and calculate total filled
    for bucket in buckets:
        fill_goals.append(bucket.fill_goal)
        total_filled.append(sum(1 for assigned_bucket in assignment.values() if assigned_bucket == bucket.name))

    # Create bar graph
    plt.figure(figsize=(10, 6))
    plt.bar(range(len(buckets)), total_filled, color='blue', label='Total Filled')
    plt.plot(fill_goals, color='red', linestyle='--', marker='o', label='Fill Goal')
    
    # Set labels and title
    plt.xlabel('Bucket')
    plt.ylabel('Count')
    plt.title('Bucket Fill Status')
    plt.xticks(range(len(buckets)), [bucket.name for bucket in buckets])
    plt.legend()
    plt.tight_layout()

    # Show plot
    plt.show()

generate_bar_graphs(buckets, assignment)

# %% [markdown]
# ## Determine the Fitness of this Assignment

# %%
fitness_1(buckets, assignment)
# Out:
# 0.7899666666666667

# %%
## Average Fitness of Random Assignment

scores = []
for i in range(1000):
    assignment = generate_random_assignment(buckets, highlighters)
    scores.append(fitness_1(buckets, assignment))

print(statistics.mean(scores))
# Out:
# 0.7254524333333333

# %% [markdown]
# # Genetic Algorithm

# %%
class GeneticAlgorithmRunner:
    def __init__(self, buckets, highlighters, mutation_rate=0.01, crossover_rate=0.1, cull_rate=0.1, max_pop=1000, max_epochs=50, fitness_function = fitness_1, generator_algorithm=generate_random_assignment):
        self.buckets = buckets
        self.highlighters = highlighters
        self.assignments = []
        self.cull_rate = cull_rate
        self.mutation_rate = mutation_rate
        self.crossover_rate = crossover_rate
        self.max_epochs = max_epochs
        self.max_population = max_pop
        self.fitness_function = fitness_function
        self.generator_algorithm = generator_algorithm

        self.population = []
                # Generate N random assignments
        for i in range(self.max_population):
            self.population.append(generator_algorithm(self.buckets, self.highlighters))

            # Select some % of fitnesses based on weights
            # selected_indices = random.choices(range(len(fitnesses)), weights=weights, k=int(self.cull_rate * len(fitnesses)))

    # Selects the top candidates 
    def cull(self, fitnesses, population):
        # Determine the number of individuals to select
        num_to_select = int(len(fitnesses) * self.cull_rate)
        
        # Create a list of indices and fitnesses
        indexed_fitnesses = list(enumerate(fitnesses))
        
        # Sort by fitness in descending order
        indexed_fitnesses.sort(key=lambda x: x[1], reverse=True)
        
        # Extract the top individuals based on sorted fitness scores
        selected_indices = [idx for idx, _ in indexed_fitnesses[:num_to_select]]
        
        # Select the fitnesses and population members by these indices
        selected_fitnesses = [fitnesses[i] for i in selected_indices]
        selected_population = [population[i] for i in selected_indices]
        
        return selected_fitnesses, selected_population

    def increase_population(self):
        """
        Increase the current population by breeding - apply mutation and crossover.
        """
        # Calculate the number of individuals needed to reach the maximum population size
        num_individuals_needed = self.max_population - len(self.population)

        original_population = self.population
        
        # Generate new individuals until the population reaches the maximum size
        while len(self.population) < self.max_population:
            # Select two parents randomly from the current population
            parent1, parent2 = random.sample(original_population, 2)
            
            offspring = self.breed(parent1, parent2)
            
            # Add the offspring to the population
            self.population.append(offspring)

    # Mutate a given individual's genes
    def mutate(self, assignment):
        for highlighter, bucket in assignment.items():
            if random.random() < self.mutation_rate:
                assignment[highlighter] = random.choice(highlighter.assignable_buckets)
        return assignment

    def crossover(self, assignment1, assignment2):
        """
        Perform crossover between two parents to produce a new individual.
        
        :param assignment1: Dictionary representing the assignment of highlighters to buckets for parent 1
        :param assignment2: Dictionary representing the assignment of highlighters to buckets for parent 2
        :return: Dictionary representing the assignment of highlighters to buckets for the offspring
        """
        # Initialize the offspring assignment
        offspring_assignment = {}

        # Randomly select genes (highlighter-bucket pairs) from each parent
        for highlighter in assignment1:
            if random.random() < 0.5:  # 50% chance to inherit from parent 1
                offspring_assignment[highlighter] = assignment1[highlighter]
            else:  # 50% chance to inherit from parent 2
                offspring_assignment[highlighter] = assignment2[highlighter]

        return offspring_assignment
    
    def breed(self, assignment1, assignment2):
        child_assignment = {}

        # Randomly make child a copy of either parent1 or parent2
        if random.random() < 0.5:
            child_assignment = assignment1
        else:
            child_assignment = assignment2

        # Probability of getting both parent's genes
        if random.random() < self.crossover_rate:
            child_assignment = self.crossover(assignment1, assignment2)

        # Mutate the genes
        child_assignment = self.mutate(child_assignment)        

        return child_assignment

    def get_best(self):
        """
        Return the highest score of the individuals in the current population.
        """
        best_score = float('-inf')  # Initialize with negative infinity to find the maximum score
        best_assignment = None
        
        # Iterate over each individual in the population
        for assignment in self.population:
            # Calculate the fitness score for the individual using the provided fitness function
            score = self.fitness_function(self.buckets, assignment)
            
            # Update the best score if the current score is higher
            if score > best_score:
                best_score = score
                best_assignment = assignment
        
        return best_assignment, best_score
        
    def run(self):
        for i in range(self.max_epochs):
            # Evaluate their fitnesses
            scores = []
            for assignment in self.population:
                scores.append(self.fitness_function(self.buckets, assignment))
    
            # Cull the herd (survival of the fittest!)
            best_scores, best_assignments = self.cull(scores, self.population)
            self.population = best_assignments

            # Breed to restore the population 
            self.increase_population()

            print(f"Epoch: {i}, Best Score: {max(best_scores)}")

            if max(best_scores) >= .9999:
                break

# %%
# generator_algorithm = random_assignment
fitness_function = fitness_1
generator_algorithm = generate_random_assignment
max_population = 1000
max_epochs = 50

a = GeneticAlgorithmRunner(buckets, highlighters, mutation_rate=0.01, crossover_rate=1.0, fitness_function=fitness_function, generator_algorithm=generator_algorithm, max_pop=max_population, max_epochs=max_epochs)
a.run()
# Out:
# Epoch: 0, Best Score: 0.7360666666666666
# Epoch: 1, Best Score: 0.7411666666666666
# Epoch: 2, Best Score: 0.7462
# Epoch: 3, Best Score: 0.7487666666666667
# Epoch: 4, Best Score: 0.7530666666666667
# Epoch: 5, Best Score: 0.7575666666666667
# Epoch: 6, Best Score: 0.7614333333333333
# Epoch: 7, Best Score: 0.7646666666666667
# Epoch: 8, Best Score: 0.7695
# Epoch: 9, Best Score: 0.7732333333333333
# Epoch: 10, Best Score: 0.7759666666666667
# Epoch: 11, Best Score: 0.7797666666666667
# Epoch: 12, Best Score: 0.7812666666666667
# Epoch: 13, Best Score: 0.7837999999999999
# Epoch: 14, Best Score: 0.7887
# Epoch: 15, Best Score: 0.7898333333333334
# Epoch: 16, Best Score: 0.7918333333333334
# Epoch: 17, Best Score: 0.7947
# Epoch: 18, Best Score: 0.7985333333333333
# Epoch: 19, Best Score: 0.8000333333333334
# Epoch: 20, Best Score: 0.8009
# Epoch: 21, Best Score: 0.8038666666666666
# Epoch: 22, Best Score: 0.8051
# Epoch: 23, Best Score: 0.8066666666666666
# Epoch: 24, Best Score: 0.8084666666666667
# Epoch: 25, Best Score: 0.8113333333333334
# Epoch: 26, Best Score: 0.8137333333333333
# Epoch: 27, Best Score: 0.8141666666666667
# Epoch: 28, Best Score: 0.8160000000000001
# Epoch: 29, Best Score: 0.8185333333333333
# Epoch: 30, Best Score: 0.8208666666666666
# Epoch: 31, Best Score: 0.8208666666666666
# Epoch: 32, Best Score: 0.823
# Epoch: 33, Best Score: 0.8249
# Epoch: 34, Best Score: 0.8257333333333333
# Epoch: 35, Best Score: 0.8275666666666667
# Epoch: 36, Best Score: 0.8279333333333333
# Epoch: 37, Best Score: 0.8293666666666667
# Epoch: 38, Best Score: 0.8308666666666666
# Epoch: 39, Best Score: 0.8310666666666666
# Epoch: 40, Best Score: 0.8342333333333334
# Epoch: 41, Best Score: 0.8345666666666667
# Epoch: 42, Best Score: 0.8348
# Epoch: 43, Best Score: 0.8361
# Epoch: 44, Best Score: 0.8382
# Epoch: 45, Best Score: 0.8383333333333334
# Epoch: 46, Best Score: 0.8395333333333334
# Epoch: 47, Best Score: 0.8395333333333334
# Epoch: 48, Best Score: 0.8410666666666666
# Epoch: 49, Best Score: 0.8422

# %%
assignment, score = a.get_best()

# %%
generate_bar_graphs(buckets, assignment)

# %%
score

# %%
assignment
# Out:
# {<__main__.Highlighter at 0x12e9b6ad0>: 'B',
#  <__main__.Highlighter at 0x12e9b9190>: 'B',
#  <__main__.Highlighter at 0x12e9b8410>: 'B',
#  <__main__.Highlighter at 0x12e9b71d0>: 'C',
#  <__main__.Highlighter at 0x104326fd0>: 'A',
#  <__main__.Highlighter at 0x12e9b5d90>: 'B',
#  <__main__.Highlighter at 0x12e9b7ad0>: 'B',
#  <__main__.Highlighter at 0x12e9b74d0>: 'E',
#  <__main__.Highlighter at 0x12e9b93d0>: 'B',
#  <__main__.Highlighter at 0x12e9b87d0>: 'D',
#  <__main__.Highlighter at 0x12e9b6110>: 'B',
#  <__main__.Highlighter at 0x12e9b9610>: 'A',
#  <__main__.Highlighter at 0x12e9b8110>: 'E',
#  <__main__.Highlighter at 0x12e9b99d0>: 'D',
#  <__main__.Highlighter at 0x12e9b9010>: 'E',
#  <__main__.Highlighter at 0x12e9b6410>: 'E',
#  <__main__.Highlighter at 0x12e9ba150>: 'D',
#  <__main__.Highlighter at 0x12e9b6f90>: 'C',
#  <__main__.Highlighter at 0x12e9b9e50>: 'C',
#  <__main__.Highlighter at 0x12e9b9910>: 'D',
#  <__main__.Highlighter at 0x12e9ba2d0>: 'C',
#  <__main__.Highlighter at 0x12e9b6d50>: 'C',
#  <__main__.Highlighter at 0x12e9b64d0>: 'A',
#  <__main__.Highlighter at 0x12e9b7950>: 'B',
#  <__main__.Highlighter at 0x12e9b7b90>: 'D',
#  <__main__.Highlighter at 0x12e9b9790>: 'A',
#  <__main__.Highlighter at 0x12e9ba090>: 'A',
#  <__main__.Highlighter at 0x12e9b7410>: 'D',
#  <__main__.Highlighter at 0x12e9b8b90>: 'B',
#  <__main__.Highlighter at 0x12e9b7110>: 'B',
#  <__main__.Highlighter at 0x12e9b7350>: 'C',
#  <__main__.Highlighter at 0x12e9b8d10>: 'D',
#  <__main__.Highlighter at 0x12e9b9850>: 'C',
#  <__main__.Highlighter at 0x12e9b77d0>: 'C',
#  <__main__.Highlighter at 0x12e9b8dd0>: 'D',
#  <__main__.Highlighter at 0x12e9b7e90>: 'C',
#  <__main__.Highlighter at 0x12e9b6ed0>: 'B',
#  <__main__.Highlighter at 0x12e9b8050>: 'C',
#  <__main__.Highlighter at 0x12e9b8c50>: 'C',
#  <__main__.Highlighter at 0x12e9b6650>: 'A',
#  <__main__.Highlighter at 0x12e9b96d0>: 'D',
#  <__main__.Highlighter at 0x12e9b81d0>: 'B',
#  <__main__.Highlighter at 0x12e9b6bd0>: 'A',
#  <__main__.Highlighter at 0x12e9b84d0>: 'C',
#  <__main__.Highlighter at 0x12e9b7dd0>: 'E',
#  <__main__.Highlighter at 0x12e9b8650>: 'C',
#  <__main__.Highlighter at 0x12e9b8f50>: 'C',
#  <__main__.Highlighter at 0x12e9b8590>: 'C',
#  <__main__.Highlighter at 0x12e9b6e10>: 'C',
#  <__main__.Highlighter at 0x12e9b8e90>: 'E',
#  <__main__.Highlighter at 0x12e9b9b50>: 'A',
#  <__main__.Highlighter at 0x12e9b7a10>: 'C',
#  <__main__.Highlighter at 0x12e9b6c90>: 'C',
#  <__main__.Highlighter at 0x12e9b5f50>: 'D',
#  <__main__.Highlighter at 0x12e9b8350>: 'B',
#  <__main__.Highlighter at 0x12e9b7290>: 'D',
#  <__main__.Highlighter at 0x12e9b6710>: 'D',
#  <__main__.Highlighter at 0x12e9ba450>: 'C',
#  <__main__.Highlighter at 0x12e9b61d0>: 'C',
#  <__main__.Highlighter at 0x12e9b6590>: 'E',
#  <__main__.Highlighter at 0x12e9b6890>: 'D',
#  <__main__.Highlighter at 0x12e9b7590>: 'B',
#  <__main__.Highlighter at 0x12e9b7c50>: 'A',
#  <__main__.Highlighter at 0x12e9ba390>: 'D',
#  <__main__.Highlighter at 0x12e9b67d0>: 'D',
#  <__main__.Highlighter at 0x12e9b7d10>: 'C',
#  <__main__.Highlighter at 0x12e9b7710>: 'C',
#  <__main__.Highlighter at 0x12e91c350>: 'D',
#  <__main__.Highlighter at 0x12e9b9c10>: 'C',
#  <__main__.Highlighter at 0x12e9b6a10>: 'C',
#  <__main__.Highlighter at 0x12e9b7890>: 'E',
#  <__main__.Highlighter at 0x12e9b6950>: 'C',
#  <__main__.Highlighter at 0x12e9b6050>: 'B',
#  <__main__.Highlighter at 0x12e9b9a90>: 'C',
#  <__main__.Highlighter at 0x12e9b7050>: 'A',
#  <__main__.Highlighter at 0x12e9b9490>: 'C',
#  <__main__.Highlighter at 0x12e9b9250>: 'B',
#  <__main__.Highlighter at 0x12e9b6090>: 'C',
#  <__main__.Highlighter at 0x12e9b9310>: 'C',
#  <__main__.Highlighter at 0x12e9b9f10>: 'D',
#  <__main__.Highlighter at 0x12e9b8890>: 'D',
#  <__main__.Highlighter at 0x12e9b6350>: 'B',
#  <__main__.Highlighter at 0x12e9b7650>: 'E',
#  <__main__.Highlighter at 0x12e9b5e10>: 'E',
#  <__main__.Highlighter at 0x12e9b5ed0>: 'B'}
